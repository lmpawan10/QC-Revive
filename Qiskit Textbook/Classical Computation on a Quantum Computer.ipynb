# %% [markdown]
# Intuitively, inner product between 2 vectors is the product of length of the 1st vector and the length of projection of 2nd vector on to the 1st vector.<br>

# %% [markdown]
# Many quantum algorithms are based around the analysis of some function f(x).
# These algos simply assume the existence of some 'black box' implementation of this function, which we can give an input x and receive the corresponding output f(x).
# This is referred to as an __Oracle__

# %% [markdown]
# One of the main forms that oracles take is of Boolean Oracles.
# Boolean oracles are described as,
# ![image.png](attachment:image.png)
# <br>
# Here, ![image-2.png](attachment:image-2.png) is used to represent a multi-qubit state consisting of 2 registers.<br>
# The 1st register is in state |x>, where x is a binary representation of the input (to function f(x)).
# Number of qubits in this register is the number of bits required to represent the inputs.<br>
# The 2nd register is used to encode the output.<br>
# The state of the 2nd register after applying Uf will be a binary representation of the output |f(x)>. This register will consist of as many qubits as required for the representaion.
# ![image-3.png](attachment:image-3.png)
# The specific results after applying Uf will depend on how we define the unitary Uf.

# %% [markdown]
# Another form of Oracle is the Phase Oracle.
# It is defined as follows,
# ![image.png](attachment:image.png)
# where output f(x) is typically a simple bit of value 0 or 1.
# <br>
# Though phase oracle seems much different from the phase oracle, it is very much another expression of the same basic idea.

# %% [markdown]
# Consider the Boolean oracle Uf that would correspond to the same function.
# It can be used as the generalised form of CNOT gate.<br>
# If f(x)=0, it leaves the output bit in state |0>.<br>
# If f(x)=1, if applies an X to flip it to |1>.<br>
# However, if the initial state of the output register were |-> rather than |0>, the effect of Uf would be to induce exactly the phase of (-1)^f(x) (required for phase oracle).
# ![image.png](attachment:image.png)

# %% [markdown]
# A unitary of the form ![image.png](attachment:image.png) is only reversible if every unique input x results in a unique output f(x), which is not true in general.
# However, we can force it to be true by simply including a copy of the input in the output.<br>
# It is what leads us to the form for Boolean oracles as we earler saw,
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# With the computation written as a unitary, we are able to consider the effect of applying it to superposition states.<br>
# Ler us take the superposition over all possible inputs x. This will result in a superposition of all possible input/output pairs.i.e,
# ![image.png](attachment:image.png)
